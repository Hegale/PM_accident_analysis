# %%
import requests
import pprint
import json

url = 'http://apis.data.go.kr/B552061/accidentRiskArea/getRestAccidentRiskArea'
params ={'serviceKey' : 'j0bcjeZvZCzEDUnE6xTlHZ/QOTIR13H6pvLgfmqAbZxD8vvXvnF9ruP0603dZnr4bgh14/D0ulzgqcg60TdN4Q==', 'searchYearCd' : '2017', 'siDo' : '11', 'guGun' : '680', 'type' : 'json', 'numOfRows' : '10', 'pageNo' : '1' }

response = requests.get(url, params=params)

# %%
contents = response.text
pp = pprint.PrettyPrinter(indent=4)

# %%
json_ob = json.loads(contents)
json_ob
# Out:
# {'resultCode': '00',
#  'resultMsg': 'NORMAL_CODE',
#  'items': {'item': [{'acc_risk_area_nm': '서울특별시 강남구내에서 2017년도에 반경50m 이내 다른사고14건 이상 지역',
#     'acc_risk_area_id': '36324',
# ...

# %%
body = json_ob['items']['item']

# %%
# dataframe으로 변환
import pandas as pd
from pandas.io.json import json_normalize
dataframe = json_normalize(body)
dataframe
# Out:
# C:\Users\Juyeon\AppData\Local\Temp\ipykernel_27344\2495884020.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   dataframe = json_normalize(body)
#                               acc_risk_area_nm acc_risk_area_id  \
# 0  서울특별시 강남구내에서 2017년도에 반경50m 이내 다른사고14건 이상 지역            36324
# 1  서울특별시 강남구내에서 2017년도에 반경50m 이내 다른사고14건 이상 지역            36325
# 2  서울특별시 강남구내에서 2017년도에 반경50m 이내 다른사고14건 이상 지역            36326
# 3  서울특별시 강남구내에서 2017년도에 반경50m 이내 다른사고14건 이상 지역            36327
# 4  서울특별시 강남구내에서 2017년도에 반경50m 이내 다른사고14건 이상 지역            36328
# 5  서울특별시 강남구내에서 2017년도에 반경50m 이내 다른사고14건 이상 지역            36329
# 6  서울특별시 강남구내에서 2017년도에 반경50m 이내 다른사고14건 이상 지역            36330
# 7  서울특별시 강남구내에서 2017년도에 반경50m 이내 다른사고14건 이상 지역            36331
# 8  서울특별시 강남구내에서 2017년도에 반경50m 이내 다른사고14건 이상 지역            36332
# 9  서울특별시 강남구내에서 2017년도에 반경50m 이내 다른사고14건 이상 지역            36333
#
# ...
