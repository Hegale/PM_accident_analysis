# %% [markdown]
# ## 도로폭이 반영된 폴리곤 자료 생성

# %%
import geopandas as gpd
import pandas as pd
import chardet

# %% [markdown]
# url = '../data/road/Z_KAIS_TL_SPRD_MANAGE_11000.shp'
# rawdata = open(url, 'rb').read()
# result = chardet.detect(rawdata)
# charenc = result['encoding']
# charenc

# %%
# linestring이 포함된 road 불러오기
road = gpd.read_file('../data/road/Z_KAIS_TL_SPRD_MANAGE_11000.shp', encoding = 'euc-kr').to_crs(5181)
# 도로 폭 정보가 포함된 roadInfo 불러오기
roadInfo = pd.read_csv('../data/road/서울시 도로노선 정보.csv', encoding='euc-kr')

# %%
# 여기서 이너조인인지 아우터조인인지?? 아무튼 도로명을 기준으로 조인
roadInfo.rename(columns={'노선명(도로명)' : 'RN'}, inplace=True)
seoul_road = pd.merge(road, roadInfo, how='inner', on='RN')
seoul_road.columns
# Out:
# Index(['ALWNC_DE', 'ALWNC_RESN', 'BSI_INT', 'ENG_RN', 'MVMN_DE', 'MVMN_RESN',
#        'MVM_RES_CD', 'NTFC_DE', 'OPERT_DE', 'RBP_CN', 'RDS_DPN_SE',
#        'RDS_MAN_NO', 'REP_CN', 'RN', 'RN_CD', 'ROAD_BT', 'ROAD_LT',
#        'ROA_CLS_SE', 'SIG_CD', 'WDR_RD_CD', 'geometry', '순번', '도로종류', '도로기능',
#        '도로규모', '도로폭', '시도구도구분'],
#       dtype='object')

# %%
# str로 된 도로폭을 구간 중간값 float로 변경
beforeReplace = ['6m미만','폭6-8m','폭8-10m','폭10-12m','폭12-15m',
                 '폭15-20m','폭20-25m','폭25-30m','폭30-35m',
                 '폭35-40m','폭40-50m','폭50-70m','폭70m이상']
afterReplace = [5.0, 7.0, 9.0, 11.0, 13.5, 17.5, 22.5,
               27.5, 32.5, 37.5, 45.0, 60.0, 70.0]
for i in range(13):
    seoul_road.replace({'도로폭':beforeReplace[i]}, afterReplace[i], inplace=True)
seoul_road
# Out:
#        ALWNC_DE                   ALWNC_RESN BSI_INT                  ENG_RN  \
# 0      20100605   용마공원로에서 분기되는 도로구간으로 일련번호부여       8  Yongmagongwon-ro 4-gil
# 1      20100605   용마공원로에서 분기되는 도로구간으로 일련번호부여      10  Yongmagongwon-ro 4-gil
# 2      20100605   용마공원로에서 분기되는 도로구간으로 일련번호부여      11  Yongmagongwon-ro 4-gil
# 3      20100605   용마공원로에서 분기되는 도로구간으로 일련번호부여       8  Yongmagongwon-ro 4-gil
# 4      20100419           중랑천의 옛 이름인 한천에서 유래      10             Hancheon-ro
# ...         ...                          ...     ...                     ...
# 67151  20160825  강남지역 동서를 연결하므로 ‘강남순환로’로 명명함      20       Gangnamsunhwan-ro
# 67152  20160825  강남지역 동서를 연결하므로 ‘강남순환로’로 명명함      20       Gangnamsunhwan-ro
# 67153  20160825  강남지역 동서를 연결하므로 ‘강남순환로’로 명명함      20       Gangnamsunhwan-ro
# 67154  20160825  강남지역 동서를 연결하므로 ‘강남순환로’로 명명함      20       Gangnamsunhwan-ro
# 67155  20170330     인접 식물원 ‘창포원’ 이름을 이용하여 명명      20           Changpowon-ro
#
#         MVMN_DE                    MVMN_RESN MVM_RES_CD   NTFC_DE  \
# 0      20181213                       도로구간변경         12  20100610
# 1          None      광역도로 정비 및 부여사유, 부여방식 정비         90  20100610
# 2          None      광역도로 정비 및 부여사유, 부여방식 정비         90  20100610
# 3          None      광역도로 정비 및 부여사유, 부여방식 정비         90  20100610
# 4      20100910      광역도로 정비 및 부여사유, 부여방식 정비         90  20100422
# ...         ...                          ...        ...       ...
# 67151  20161018                   직권수정(속성변경)         99  20160825
# 67152  20161018                   직권수정(속성변경)         99  20160825
# 67153  20161018  강남지역 동서를 연결하므로 ‘강남순환로’로 명명함         01  20160825
# 67154  20161018  강남지역 동서를 연결하므로 ‘강남순환로’로 명명함         01  20160825
# 67155  20170516     인접 식물원 ‘창포원’ 이름을 이용하여 명명         01  20170330
#
#              OPERT_DE           RBP_CN  ... ROA_CLS_SE  SIG_CD WDR_RD_CD  \
# 0      20181213150729        망우동 408-1  ...          4   11260         3
# 1            20100928        망우동 408-1  ...          4   11260         3
# 2            20100928        망우동 408-1  ...          4   11260         3
# 3            20100928        망우동 408-1  ...          4   11260         3
# 4      20141030220124       석관동 42-12대  ...          3   11290         2
# ...               ...              ...  ...        ...     ...       ...
# 67151  20200508110438     경기도 광명시 소하JC  ...          3   11620         1
# 67152  20200508110438     경기도 광명시 소하JC  ...          3   11620         1
# 67153  20161018194703     경기도 광명시 소하JC  ...          3   11650         1
# 67154  20161018194703     경기도 광명시 소하JC  ...          3   11650         1
# 67155  20170516095532  서울시 도봉구 마들로 886  ...          3   11320         1
#
#                                                 geometry     순번     도로종류  \
# 0      LINESTRING (208800.320 454558.970, 208819.316 ...  30208     일반도로
# 1      LINESTRING (208801.989 454562.860, 208777.079 ...  30208     일반도로
# 2      LINESTRING (208858.493 454690.612, 208850.216 ...  30208     일반도로
# 3      LINESTRING (208829.004 454625.298, 208814.696 ...  30208     일반도로
# 4      LINESTRING (205057.501 456982.948, 205054.066 ...  33215     일반도로
# ...                                                  ...    ...      ...
# 67151  LINESTRING (193589.198 438763.940, 193589.486 ...    289  자동차전용도로
# 67152  LINESTRING (193589.198 438763.940, 193589.486 ...    290     일반도로
# 67153  LINESTRING (198562.130 440873.011, 198645.736 ...    289  자동차전용도로
# 67154  LINESTRING (198562.130 440873.011, 198645.736 ...    290     일반도로
# 67155  LINESTRING (204273.917 465083.998, 204268.918 ...  32171      NaN
#
#          도로기능  도로규모   도로폭 시도구도구분
# 0        국지도로    소로   5.0     구도
# 1        국지도로    소로   5.0     구도
# 2        국지도로    소로   5.0     구도
# 3        국지도로    소로   5.0     구도
# 4        국지도로    소로   5.0     구도
# ...       ...   ...   ...    ...
# 67151  도시고속도로  광로3류  45.0   특별시도
# 67152    국지도로  중로3류  13.5     구도
# 67153  도시고속도로  광로3류  45.0   특별시도
# 67154    국지도로  중로3류  13.5     구도
# 67155    국지도로    소로   5.0     구도
#
# [67156 rows x 27 columns]

# %%
# buffer
buff_road = seoul_road.buffer(seoul_road['도로폭'])
# buffer된 폴리곤을 기존 linestring 속성과 대체
seoul_road.geometry = buff_road
seoul_road
# Out:
#        ALWNC_DE                   ALWNC_RESN BSI_INT                  ENG_RN  \
# 0      20100605   용마공원로에서 분기되는 도로구간으로 일련번호부여       8  Yongmagongwon-ro 4-gil
# 1      20100605   용마공원로에서 분기되는 도로구간으로 일련번호부여      10  Yongmagongwon-ro 4-gil
# 2      20100605   용마공원로에서 분기되는 도로구간으로 일련번호부여      11  Yongmagongwon-ro 4-gil
# 3      20100605   용마공원로에서 분기되는 도로구간으로 일련번호부여       8  Yongmagongwon-ro 4-gil
# 4      20100419           중랑천의 옛 이름인 한천에서 유래      10             Hancheon-ro
# ...         ...                          ...     ...                     ...
# 67151  20160825  강남지역 동서를 연결하므로 ‘강남순환로’로 명명함      20       Gangnamsunhwan-ro
# 67152  20160825  강남지역 동서를 연결하므로 ‘강남순환로’로 명명함      20       Gangnamsunhwan-ro
# 67153  20160825  강남지역 동서를 연결하므로 ‘강남순환로’로 명명함      20       Gangnamsunhwan-ro
# 67154  20160825  강남지역 동서를 연결하므로 ‘강남순환로’로 명명함      20       Gangnamsunhwan-ro
# 67155  20170330     인접 식물원 ‘창포원’ 이름을 이용하여 명명      20           Changpowon-ro
#
#         MVMN_DE                    MVMN_RESN MVM_RES_CD   NTFC_DE  \
# 0      20181213                       도로구간변경         12  20100610
# 1          None      광역도로 정비 및 부여사유, 부여방식 정비         90  20100610
# 2          None      광역도로 정비 및 부여사유, 부여방식 정비         90  20100610
# 3          None      광역도로 정비 및 부여사유, 부여방식 정비         90  20100610
# 4      20100910      광역도로 정비 및 부여사유, 부여방식 정비         90  20100422
# ...         ...                          ...        ...       ...
# 67151  20161018                   직권수정(속성변경)         99  20160825
# 67152  20161018                   직권수정(속성변경)         99  20160825
# 67153  20161018  강남지역 동서를 연결하므로 ‘강남순환로’로 명명함         01  20160825
# 67154  20161018  강남지역 동서를 연결하므로 ‘강남순환로’로 명명함         01  20160825
# 67155  20170516     인접 식물원 ‘창포원’ 이름을 이용하여 명명         01  20170330
#
#              OPERT_DE           RBP_CN  ... ROA_CLS_SE  SIG_CD WDR_RD_CD  \
# 0      20181213150729        망우동 408-1  ...          4   11260         3
# 1            20100928        망우동 408-1  ...          4   11260         3
# 2            20100928        망우동 408-1  ...          4   11260         3
# 3            20100928        망우동 408-1  ...          4   11260         3
# 4      20141030220124       석관동 42-12대  ...          3   11290         2
# ...               ...              ...  ...        ...     ...       ...
# 67151  20200508110438     경기도 광명시 소하JC  ...          3   11620         1
# 67152  20200508110438     경기도 광명시 소하JC  ...          3   11620         1
# 67153  20161018194703     경기도 광명시 소하JC  ...          3   11650         1
# 67154  20161018194703     경기도 광명시 소하JC  ...          3   11650         1
# 67155  20170516095532  서울시 도봉구 마들로 886  ...          3   11320         1
#
#                                                 geometry     순번     도로종류  \
# 0      POLYGON ((208821.393 454554.846, 208821.828 45...  30208     일반도로
# 1      POLYGON ((208775.066 454569.242, 208774.627 45...  30208     일반도로
# 2      POLYGON ((208854.737 454670.952, 208854.716 45...  30208     일반도로
# 3      POLYGON ((208812.695 454626.965, 208812.255 45...  30208     일반도로
# 4      POLYGON ((205051.276 456981.148, 205042.628 45...  33215     일반도로
# ...                                                  ...    ...      ...
# 67151  POLYGON ((193559.038 438797.339, 193562.697 43...    289  자동차전용도로
# 67152  POLYGON ((193580.351 438774.144, 193584.025 43...    290     일반도로
# 67153  POLYGON ((198639.020 440930.125, 198639.338 44...    289  자동차전용도로
# 67154  POLYGON ((198643.721 440898.978, 198643.816 44...    290     일반도로
# 67155  POLYGON ((204263.927 465380.319, 204258.847 46...  32171      NaN
#
#          도로기능  도로규모   도로폭 시도구도구분
# 0        국지도로    소로   5.0     구도
# 1        국지도로    소로   5.0     구도
# 2        국지도로    소로   5.0     구도
# 3        국지도로    소로   5.0     구도
# 4        국지도로    소로   5.0     구도
# ...       ...   ...   ...    ...
# 67151  도시고속도로  광로3류  45.0   특별시도
# 67152    국지도로  중로3류  13.5     구도
# 67153  도시고속도로  광로3류  45.0   특별시도
# 67154    국지도로  중로3류  13.5     구도
# 67155    국지도로    소로   5.0     구도
#
# [67156 rows x 27 columns]

# %%
seoul_road.plot()
# Out:
# <AxesSubplot:>

# %%
# geojson은 용량이넘커여
buff_road.to_file('../data/road/buff_road.shp', encoding='euc-kr')
# Out:
# C:\miniforge\envs\gis\lib\site-packages\geopandas\io\file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %%
seoul_road[seoul_road['RN'] == '%가양%']
# Out:
# Empty GeoDataFrame
# Columns: [ALWNC_DE, ALWNC_RESN, BSI_INT, ENG_RN, MVMN_DE, MVMN_RESN, MVM_RES_CD, NTFC_DE, OPERT_DE, RBP_CN, RDS_DPN_SE, RDS_MAN_NO, REP_CN, RN, RN_CD, ROAD_BT, ROAD_LT, ROA_CLS_SE, SIG_CD, WDR_RD_CD, geometry, 순번, 도로종류, 도로기능, 도로규모, 도로폭, 시도구도구분]
# Index: []
#
# [0 rows x 27 columns]

# %%
traffic = pd.read_csv("../data/road/총 교통량_지점별.csv", encoding='euc-kr')
traffic.rename(columns = {'지점명' : 'RN'}, inplace=True)
traffic
# Out:
#                 RN        총 교통량
# 0             가양대교  118955174.0
# 1    강남대로(강남역-신분당)   59750813.0
# 2        강남대로(신사역)   80739243.0
# 3             강동대교    4291290.0
# 4             강변북로  252713339.0
# ..             ...          ...
# 201     국회대로(여의5교)      14702.0
# 202     국회대로(여의6교)      21340.0
# 203     국회대로(여의7교)      15974.0
# 204     국회대로(여의8교)      22341.0
# 205     국회대로(여의9교)      30732.0
#
# [206 rows x 2 columns]

# %%
# seoul_road에 교통량 속성 추가. traffic의 '지점명'과 seoul_road의 'RN' 속성이 같은 조건으로
road_traffic = pd.merge(seoul_road, traffic, on='RN', how = 'left')
road_traffic
# Out:
#        ALWNC_DE                   ALWNC_RESN BSI_INT                  ENG_RN  \
# 0      20100605   용마공원로에서 분기되는 도로구간으로 일련번호부여       8  Yongmagongwon-ro 4-gil
# 1      20100605   용마공원로에서 분기되는 도로구간으로 일련번호부여      10  Yongmagongwon-ro 4-gil
# 2      20100605   용마공원로에서 분기되는 도로구간으로 일련번호부여      11  Yongmagongwon-ro 4-gil
# 3      20100605   용마공원로에서 분기되는 도로구간으로 일련번호부여       8  Yongmagongwon-ro 4-gil
# 4      20100419           중랑천의 옛 이름인 한천에서 유래      10             Hancheon-ro
# ...         ...                          ...     ...                     ...
# 67151  20160825  강남지역 동서를 연결하므로 ‘강남순환로’로 명명함      20       Gangnamsunhwan-ro
# 67152  20160825  강남지역 동서를 연결하므로 ‘강남순환로’로 명명함      20       Gangnamsunhwan-ro
# 67153  20160825  강남지역 동서를 연결하므로 ‘강남순환로’로 명명함      20       Gangnamsunhwan-ro
# 67154  20160825  강남지역 동서를 연결하므로 ‘강남순환로’로 명명함      20       Gangnamsunhwan-ro
# 67155  20170330     인접 식물원 ‘창포원’ 이름을 이용하여 명명      20           Changpowon-ro
#
#         MVMN_DE                    MVMN_RESN MVM_RES_CD   NTFC_DE  \
# 0      20181213                       도로구간변경         12  20100610
# 1          None      광역도로 정비 및 부여사유, 부여방식 정비         90  20100610
# 2          None      광역도로 정비 및 부여사유, 부여방식 정비         90  20100610
# 3          None      광역도로 정비 및 부여사유, 부여방식 정비         90  20100610
# 4      20100910      광역도로 정비 및 부여사유, 부여방식 정비         90  20100422
# ...         ...                          ...        ...       ...
# 67151  20161018                   직권수정(속성변경)         99  20160825
# 67152  20161018                   직권수정(속성변경)         99  20160825
# 67153  20161018  강남지역 동서를 연결하므로 ‘강남순환로’로 명명함         01  20160825
# 67154  20161018  강남지역 동서를 연결하므로 ‘강남순환로’로 명명함         01  20160825
# 67155  20170516     인접 식물원 ‘창포원’ 이름을 이용하여 명명         01  20170330
#
#              OPERT_DE           RBP_CN  ... SIG_CD  WDR_RD_CD  \
# 0      20181213150729        망우동 408-1  ...  11260          3
# 1            20100928        망우동 408-1  ...  11260          3
# 2            20100928        망우동 408-1  ...  11260          3
# 3            20100928        망우동 408-1  ...  11260          3
# 4      20141030220124       석관동 42-12대  ...  11290          2
# ...               ...              ...  ...    ...        ...
# 67151  20200508110438     경기도 광명시 소하JC  ...  11620          1
# 67152  20200508110438     경기도 광명시 소하JC  ...  11620          1
# 67153  20161018194703     경기도 광명시 소하JC  ...  11650          1
# 67154  20161018194703     경기도 광명시 소하JC  ...  11650          1
# 67155  20170516095532  서울시 도봉구 마들로 886  ...  11320          1
#
#                                                 geometry     순번     도로종류  \
# 0      POLYGON ((208821.393 454554.846, 208821.828 45...  30208     일반도로
# 1      POLYGON ((208775.066 454569.242, 208774.627 45...  30208     일반도로
# 2      POLYGON ((208854.737 454670.952, 208854.716 45...  30208     일반도로
# 3      POLYGON ((208812.695 454626.965, 208812.255 45...  30208     일반도로
# 4      POLYGON ((205051.276 456981.148, 205042.628 45...  33215     일반도로
# ...                                                  ...    ...      ...
# 67151  POLYGON ((193559.038 438797.339, 193562.697 43...    289  자동차전용도로
# 67152  POLYGON ((193580.351 438774.144, 193584.025 43...    290     일반도로
# 67153  POLYGON ((198639.020 440930.125, 198639.338 44...    289  자동차전용도로
# 67154  POLYGON ((198643.721 440898.978, 198643.816 44...    290     일반도로
# 67155  POLYGON ((204263.927 465380.319, 204258.847 46...  32171      NaN
#
#          도로기능  도로규모   도로폭 시도구도구분       총 교통량
# 0        국지도로    소로   5.0     구도         NaN
# 1        국지도로    소로   5.0     구도         NaN
# 2        국지도로    소로   5.0     구도         NaN
# 3        국지도로    소로   5.0     구도         NaN
# 4        국지도로    소로   5.0     구도         NaN
# ...       ...   ...   ...    ...         ...
# 67151  도시고속도로  광로3류  45.0   특별시도  51842458.0
# 67152    국지도로  중로3류  13.5     구도  51842458.0
# 67153  도시고속도로  광로3류  45.0   특별시도  51842458.0
# 67154    국지도로  중로3류  13.5     구도  51842458.0
# 67155    국지도로    소로   5.0     구도         NaN
#
# [67156 rows x 28 columns]

# %%
road_traffic.to_csv('../data/road/road_traffic.csv', encoding='euc-kr')

# %%
# 왜 seoul road를 euckr로 내보내면 UnicodeDecodeError 오류나지?? 그걸로 불러왔는데???
# seoul_road.to_csv('../data/road/seoul_road.csv', encoding='euc-kr')
